# %% [markdown]
# <a href="https://colab.research.google.com/github/thinkxstudy/think_study/blob/master/Adjfinder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
sentence = "holy shit great"
nltk.download()
text = nltk.word_tokenize(sentence)
nltk.pos_tag(text)
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q
# [('holy', 'NN'), ('shit', 'VBD'), ('great', 'JJ')]
